# %% [markdown]
# Practice pandas with the help of created datafram and perform data manipulation on it

# %%
import pandas as pd

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : 0691c5cf90477d3503834d983f69350f250a6ff7
# python                : 3.12.3
# python-bits           : 64
# OS                    : Windows
# OS-release            : 10
# Version               : 10.0.17763
# machine               : AMD64
# processor             : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : English_United States.1252
#
# pandas                : 2.2.3
# numpy                 : 2.2.4
# pytz                  : 2025.1
# dateutil              : 2.9.0.post0
# pip                   : 24.0
# Cython                : None
# sphinx                : None
# IPython               : 9.0.2
# adbc-driver-postgresql: None
# adbc-driver-sqlite    : None
# bs4                   : None
# blosc                 : None
# bottleneck            : None
# dataframe-api-compat  : None
# ...

# %%
df = pd.DataFrame({'Name': ['NAzeer', 'Asiya','NAzeer', 'Asiya','NAzeer', 'Asiya','NAzeer', 'Asiya','NAzeer', 'Asiya','NAzeer', 'Asiya',
                            'NAzeer', 'Asiya','NAzeer', 'Asiya','NAzeer', 'Asiya','NAzeer', 'Asiya'], 
                            'Age': [20, 19,20, 19,20, 19,20, 19,20, 19,20, 19,20, 19,20, 19,20, 19,20, 19]})
df
# Out:
#       Name  Age
# 0   NAzeer   20
# 1    Asiya   19
# 2   NAzeer   20
# 3    Asiya   19
# 4   NAzeer   20
# 5    Asiya   19
# 6   NAzeer   20
# 7    Asiya   19
# 8   NAzeer   20
# 9    Asiya   19
# 10  NAzeer   20
# 11   Asiya   19
# 12  NAzeer   20
# 13   Asiya   19
# 14  NAzeer   20
# 15   Asiya   19
# 16  NAzeer   20
# 17   Asiya   19
# 18  NAzeer   20
# 19   Asiya   19

# %%
df.shape
# Out:
# (20, 2)

# %%
df.rename(columns={'Name':'NAME','Age':'AGE'},inplace=True)
df
# Out:
#       NAME  AGE
# 0   NAzeer   20
# 1    Asiya   19
# 2   NAzeer   20
# 3    Asiya   19
# 4   NAzeer   20
# 5    Asiya   19
# 6   NAzeer   20
# 7    Asiya   19
# 8   NAzeer   20
# 9    Asiya   19
# 10  NAzeer   20
# 11   Asiya   19
# 12  NAzeer   20
# 13   Asiya   19
# 14  NAzeer   20
# 15   Asiya   19
# 16  NAzeer   20
# 17   Asiya   19
# 18  NAzeer   20
# 19   Asiya   19

# %%
df.add_prefix('*')
# Out:
#      *NAME  *AGE
# 0   NAzeer    20
# 1    Asiya    19
# 2   NAzeer    20
# 3    Asiya    19
# 4   NAzeer    20
# 5    Asiya    19
# 6   NAzeer    20
# 7    Asiya    19
# 8   NAzeer    20
# 9    Asiya    19
# 10  NAzeer    20
# 11   Asiya    19
# 12  NAzeer    20
# 13   Asiya    19
# 14  NAzeer    20
# 15   Asiya    19
# 16  NAzeer    20
# 17   Asiya    19
# 18  NAzeer    20
# 19   Asiya    19

# %%
df.add_suffix("*")
# Out:
#      NAME*  AGE*
# 0   NAzeer    20
# 1    Asiya    19
# 2   NAzeer    20
# 3    Asiya    19
# 4   NAzeer    20
# 5    Asiya    19
# 6   NAzeer    20
# 7    Asiya    19
# 8   NAzeer    20
# 9    Asiya    19
# 10  NAzeer    20
# 11   Asiya    19
# 12  NAzeer    20
# 13   Asiya    19
# 14  NAzeer    20
# 15   Asiya    19
# 16  NAzeer    20
# 17   Asiya    19
# 18  NAzeer    20
# 19   Asiya    19

# %%
df
# Out:
#       NAME  AGE
# 0   NAzeer   20
# 1    Asiya   19
# 2   NAzeer   20
# 3    Asiya   19
# 4   NAzeer   20
# 5    Asiya   19
# 6   NAzeer   20
# 7    Asiya   19
# 8   NAzeer   20
# 9    Asiya   19
# 10  NAzeer   20
# 11   Asiya   19
# 12  NAzeer   20
# 13   Asiya   19
# 14  NAzeer   20
# 15   Asiya   19
# 16  NAzeer   20
# 17   Asiya   19
# 18  NAzeer   20
# 19   Asiya   19

# %%
df.head()
# Out:
#      NAME  AGE
# 0  NAzeer   20
# 1   Asiya   19
# 2  NAzeer   20
# 3   Asiya   19
# 4  NAzeer   20

# %%
df.tail()
# Out:
#       NAME  AGE
# 15   Asiya   19
# 16  NAzeer   20
# 17   Asiya   19
# 18  NAzeer   20
# 19   Asiya   19

# %%
df.T
# Out:
#           0      1       2      3       4      5       6      7       8   \
# NAME  NAzeer  Asiya  NAzeer  Asiya  NAzeer  Asiya  NAzeer  Asiya  NAzeer
# AGE       20     19      20     19      20     19      20     19      20
#
#          9       10     11      12     13      14     15      16     17  \
# NAME  Asiya  NAzeer  Asiya  NAzeer  Asiya  NAzeer  Asiya  NAzeer  Asiya
# AGE      19      20     19      20     19      20     19      20     19
#
#           18     19
# NAME  NAzeer  Asiya
# AGE       20     19

# %%
df.describe()
# Out:
#              AGE
# count  20.000000
# mean   19.500000
# std     0.512989
# min    19.000000
# 25%    19.000000
# 50%    19.500000
# 75%    20.000000
# max    20.000000

# %%
df.shape
# Out:
# (20, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    20 non-null     object
#  1   AGE     20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 452.0+ bytes

# %%
df.dtypes
# Out:
# NAME    object
# AGE      int64
# dtype: object

# %%
df.sample()
# Out:
#      NAME  AGE
# 6  NAzeer   20

# %%
df.mode()
# Out:
#      NAME  AGE
# 0   Asiya   19
# 1  NAzeer   20

# %%
df.to_csv('data.csv')

# %%
pd.read_csv('data.csv')
# Out:
#     Unnamed: 0    NAME  AGE
# 0            0  NAzeer   20
# 1            1   Asiya   19
# 2            2  NAzeer   20
# 3            3   Asiya   19
# 4            4  NAzeer   20
# 5            5   Asiya   19
# 6            6  NAzeer   20
# 7            7   Asiya   19
# 8            8  NAzeer   20
# 9            9   Asiya   19
# 10          10  NAzeer   20
# 11          11   Asiya   19
# 12          12  NAzeer   20
# 13          13   Asiya   19
# 14          14  NAzeer   20
# 15          15   Asiya   19
# 16          16  NAzeer   20
# 17          17   Asiya   19
# 18          18  NAzeer   20
# 19          19   Asiya   19

# %%
df.loc[::1]
# Out:
#       NAME  AGE
# 0   NAzeer   20
# 1    Asiya   19
# 2   NAzeer   20
# 3    Asiya   19
# 4   NAzeer   20
# 5    Asiya   19
# 6   NAzeer   20
# 7    Asiya   19
# 8   NAzeer   20
# 9    Asiya   19
# 10  NAzeer   20
# 11   Asiya   19
# 12  NAzeer   20
# 13   Asiya   19
# 14  NAzeer   20
# 15   Asiya   19
# 16  NAzeer   20
# 17   Asiya   19
# 18  NAzeer   20
# 19   Asiya   19

# %%
df.loc[::-1]
# Out:
#       NAME  AGE
# 19   Asiya   19
# 18  NAzeer   20
# 17   Asiya   19
# 16  NAzeer   20
# 15   Asiya   19
# 14  NAzeer   20
# 13   Asiya   19
# 12  NAzeer   20
# 11   Asiya   19
# 10  NAzeer   20
# 9    Asiya   19
# 8   NAzeer   20
# 7    Asiya   19
# 6   NAzeer   20
# 5    Asiya   19
# 4   NAzeer   20
# 3    Asiya   19
# 2   NAzeer   20
# 1    Asiya   19
# 0   NAzeer   20

# %%
df['NAME']
# Out:
# 0     NAzeer
# 1      Asiya
# 2     NAzeer
# 3      Asiya
# 4     NAzeer
# 5      Asiya
# 6     NAzeer
# 7      Asiya
# 8     NAzeer
# 9      Asiya
# 10    NAzeer
# 11     Asiya
# 12    NAzeer
# 13     Asiya
# 14    NAzeer
# 15     Asiya
# 16    NAzeer
# 17     Asiya
# 18    NAzeer
# 19     Asiya
# Name: NAME, dtype: object

# %%
df['AGE']
# Out:
# 0     20
# 1     19
# 2     20
# 3     19
# 4     20
# 5     19
# 6     20
# 7     19
# 8     20
# 9     19
# 10    20
# 11    19
# 12    20
# 13    19
# 14    20
# 15    19
# 16    20
# 17    19
# 18    20
# 19    19
# Name: AGE, dtype: int64

# %%
df.select_dtypes(include=['number'])
# Out:
#     AGE
# 0    20
# 1    19
# 2    20
# 3    19
# 4    20
# 5    19
# 6    20
# 7    19
# 8    20
# 9    19
# 10   20
# 11   19
# 12   20
# 13   19
# 14   20
# 15   19
# 16   20
# 17   19
# 18   20
# 19   19

# %%
df.select_dtypes(exclude=['number'])
# Out:
#       NAME
# 0   NAzeer
# 1    Asiya
# 2   NAzeer
# 3    Asiya
# 4   NAzeer
# 5    Asiya
# 6   NAzeer
# 7    Asiya
# 8   NAzeer
# 9    Asiya
# 10  NAzeer
# 11   Asiya
# 12  NAzeer
# 13   Asiya
# 14  NAzeer
# 15   Asiya
# 16  NAzeer
# 17   Asiya
# 18  NAzeer
# 19   Asiya

# %%
df.sample(frac=0.1)
# Out:
#       NAME  AGE
# 4   NAzeer   20
# 10  NAzeer   20

# %%
df= df.sample(frac = 0.50, random_state=1)
df
# Out:
#       NAME  AGE
# 3    Asiya   19
# 16  NAzeer   20
# 6   NAzeer   20
# 10  NAzeer   20
# 2   NAzeer   20
# 14  NAzeer   20
# 4   NAzeer   20
# 17   Asiya   19
# 7    Asiya   19
# 1    Asiya   19

# %%
# df=df.drop(df.index)
# df

# %%
df1=df.sample(frac=0.150)
df1
# Out:
#      NAME  AGE
# 2  NAzeer   20
# 7   Asiya   19

# %%
df2=df.sample(frac=0.150)
df2
# Out:
#       NAME  AGE
# 17   Asiya   19
# 2   NAzeer   20

# %%
df1+df2
# Out:
#             NAME   AGE
# 2   NAzeerNAzeer  40.0
# 7            NaN   NaN
# 17           NaN   NaN

# %%
len(df)
# Out:
# 10

# %%
df.AGE.unique()
# Out:
# array([19, 20])

# %%
df.AGE.value_counts().nlargest(1)
# Out:
# AGE
# 20    6
# Name: count, dtype: int64

# %%
df.AGE.value_counts().nsmallest(1)
# Out:
# AGE
# 19    4
# Name: count, dtype: int64

# %%
df.NAME.str.split(' ',expand=True)
# Out:
#          0
# 3    Asiya
# 16  NAzeer
# 6   NAzeer
# 10  NAzeer
# 2   NAzeer
# 14  NAzeer
# 4   NAzeer
# 17   Asiya
# 7    Asiya
# 1    Asiya

# %%
len(df.groupby('NAME'))
# Out:
# 2

# %%
df.AGE.mean()
# Out:
# np.float64(19.6)

# %%
df.describe().loc[['min' ,'max']]
# Out:
#       AGE
# min  19.0
# max  20.0
